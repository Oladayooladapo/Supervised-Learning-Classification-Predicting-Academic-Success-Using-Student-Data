# %% [markdown]
# # Import packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the Dataset

# %%
data = pd.read_csv("Student_performance_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  StudentID  Age  Gender  Ethnicity ParentalEducation  \
# 0           0       1001   17  Female  Caucasian      Some College
# 1           1       1002   18    Male  Caucasian       High School
# 2           2       1003   15    Male      Asian        Bachelor's
# 3           3       1004   17  Female  Caucasian        Bachelor's
# 4           4       1005   17  Female  Caucasian      Some College
#
#    StudyTimeWeekly  Absences  Tutoring ParentalSupport  Extracurricular  \
# 0        19.833723         7         1        Moderate                0
# 1        15.408756         0         0             Low                0
# 2         4.210570        26         0        Moderate                0
# 3        10.028829        14         0            High                1
# 4         4.672495        17         1            High                0
#
#    Sports  Music  Volunteering       GPA  GradeClass
# 0       0      1             0  2.929196         2.0
# ...

# %% [markdown]
# #### Quick basic stats on the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2392 non-null   int64
#  1   StudentID          2392 non-null   int64
#  2   Age                2392 non-null   int64
#  3   Gender             2392 non-null   object
#  4   Ethnicity          2392 non-null   object
#  5   ParentalEducation  2392 non-null   object
#  6   StudyTimeWeekly    2392 non-null   float64
#  7   Absences           2392 non-null   int64
#  8   Tutoring           2392 non-null   int64
#  9   ParentalSupport    2392 non-null   object
#  10  Extracurricular    2392 non-null   int64
#  11  Sports             2392 non-null   int64
#  12  Music              2392 non-null   int64
#  13  Volunteering       2392 non-null   int64
#  14  GPA                2392 non-null   float64
#  15  GradeClass         2392 non-null   float64
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0    StudentID          Age  StudyTimeWeekly     Absences  \
# count  2392.000000  2392.000000  2392.000000      2392.000000  2392.000000
# mean   1195.500000  2196.500000    16.468645         9.771992    14.541388
# std     690.655244   690.655244     1.123798         5.652774     8.467417
# min       0.000000  1001.000000    15.000000         0.001057     0.000000
# 25%     597.750000  1598.750000    15.000000         5.043079     7.000000
# 50%    1195.500000  2196.500000    16.000000         9.705363    15.000000
# 75%    1793.250000  2794.250000    17.000000        14.408410    22.000000
# max    2391.000000  3392.000000    18.000000        19.978094    29.000000
#
#           Tutoring  Extracurricular       Sports        Music  Volunteering  \
# count  2392.000000      2392.000000  2392.000000  2392.000000   2392.000000
# mean      0.301421         0.383361     0.303512     0.196906      0.157191
# ...

# %%
data.describe(include="object")
# Out:
#         Gender  Ethnicity ParentalEducation ParentalSupport
# count     2392       2392              2392            2392
# unique       2          4                 5               5
# top     Female  Caucasian      Some College        Moderate
# freq      1222       1207               934             740

# %% [markdown]
# ### Handling Missing Values

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
data.isnull().mean() *100
# Out:
# Unnamed: 0           0.0
# StudentID            0.0
# Age                  0.0
# Gender               0.0
# Ethnicity            0.0
# ParentalEducation    0.0
# StudyTimeWeekly      0.0
# Absences             0.0
# Tutoring             0.0
# ParentalSupport      0.0
# Extracurricular      0.0
# Sports               0.0
# Music                0.0
# Volunteering         0.0
# GPA                  0.0
# GradeClass           0.0
# dtype: float64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %% [markdown]
# ### Check for duplicate

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Cleaning

# %%
data.head()
# Out:
#    Unnamed: 0  StudentID  Age  Gender  Ethnicity ParentalEducation  \
# 0           0       1001   17  Female  Caucasian      Some College
# 1           1       1002   18    Male  Caucasian       High School
# 2           2       1003   15    Male      Asian        Bachelor's
# 3           3       1004   17  Female  Caucasian        Bachelor's
# 4           4       1005   17  Female  Caucasian      Some College
#
#    StudyTimeWeekly  Absences  Tutoring ParentalSupport  Extracurricular  \
# 0        19.833723         7         1        Moderate                0
# 1        15.408756         0         0             Low                0
# 2         4.210570        26         0        Moderate                0
# 3        10.028829        14         0            High                1
# 4         4.672495        17         1            High                0
#
#    Sports  Music  Volunteering       GPA  GradeClass
# 0       0      1             0  2.929196         2.0
# ...

# %%
data['Extracurricular'].value_counts()
# Out:
# 0    1475
# 1     917
# Name: Extracurricular, dtype: int64

# %%
data = data.drop(["Unnamed: 0",	"StudentID"], axis=1)

# %%
data.head()
# Out:
#    Age  Gender  Ethnicity ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17  Female  Caucasian      Some College        19.833723         7
# 1   18    Male  Caucasian       High School        15.408756         0
# 2   15    Male      Asian        Bachelor's         4.210570        26
# 3   17  Female  Caucasian        Bachelor's        10.028829        14
# 4   17  Female  Caucasian      Some College         4.672495        17
#
#    Tutoring ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1        Moderate                0       0      1             0
# 1         0             Low                0       0      0             0
# 2         0        Moderate                0       0      0             0
# 3         0            High                1       0      0             0
# 4         1            High                0       0      0             0
#
#         GPA  GradeClass
# 0  2.929196         2.0
# 1  3.042915         1.0
# ...

# %% [markdown]
# # Univariate Analysis

# %%
numerical_data = data.select_dtypes(exclude="object")

# %%
numerical_data.head()
# Out:
#    Age  StudyTimeWeekly  Absences  Tutoring  Extracurricular  Sports  Music  \
# 0   17        19.833723         7         1                0       0      1
# 1   18        15.408756         0         0                0       0      0
# 2   15         4.210570        26         0                0       0      0
# 3   17        10.028829        14         0                1       0      0
# 4   17         4.672495        17         1                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0

# %%
categorical_data = data.select_dtypes(include="object")

# %%
categorical_data.head()
# Out:
#    Gender  Ethnicity ParentalEducation ParentalSupport
# 0  Female  Caucasian      Some College        Moderate
# 1    Male  Caucasian       High School             Low
# 2    Male      Asian        Bachelor's        Moderate
# 3  Female  Caucasian        Bachelor's            High
# 4  Female  Caucasian      Some College            High

# %%
len(numerical_data.columns)
# Out:
# 10

# %%
for index, column_name in enumerate(numerical_data):
    print(column_name)
# Out:
# Age
# StudyTimeWeekly
# Absences
# Tutoring
# Extracurricular
# Sports
# Music
# Volunteering
# GPA
# GradeClass

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(20, 25))
ax = axes.flatten()

for index, column_name in enumerate(numerical_data):
    sns.histplot(data[column_name], ax=ax[index], kde=True, color="Orange")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(20, 25))
ax = axes.flatten()

for index, column_name in enumerate(numerical_data):
    sns.boxplot(data[column_name], ax=ax[index], color="Orange")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bi-Variate Analysis

# %%
numerical_data.corr()
# Out:
#                       Age  StudyTimeWeekly  Absences  Tutoring  \
# Age              1.000000        -0.006800 -0.011511 -0.012076
# StudyTimeWeekly -0.006800         1.000000  0.009326  0.028930
# Absences        -0.011511         0.009326  1.000000 -0.015534
# Tutoring        -0.012076         0.028930 -0.015534  1.000000
# Extracurricular -0.025061        -0.022860  0.000360  0.004865
# Sports          -0.046320         0.006836  0.041454  0.006278
# Music           -0.003492         0.007791 -0.008692 -0.011385
# Volunteering     0.013074        -0.016604 -0.018528 -0.050898
# GPA              0.000275         0.179275 -0.919314  0.145119
# GradeClass      -0.006250        -0.134131  0.728633 -0.111695
#
#                  Extracurricular    Sports     Music  Volunteering       GPA  \
# Age                    -0.025061 -0.046320 -0.003492      0.013074  0.000275
# StudyTimeWeekly        -0.022860  0.006836  0.007791     -0.016604  0.179275
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(numerical_data.corr(), annot=True, fmt=".2f", cmap="Set1")
# Out:
# <Axes: >

# %% [markdown]
# ### Univariate - Categorical

# %%
categorical_data.head()
# Out:
#    Gender  Ethnicity ParentalEducation ParentalSupport
# 0  Female  Caucasian      Some College        Moderate
# 1    Male  Caucasian       High School             Low
# 2    Male      Asian        Bachelor's        Moderate
# 3  Female  Caucasian        Bachelor's            High
# 4  Female  Caucasian      Some College            High

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 15))
ax = axes.flatten()

for index, column_name in enumerate(categorical_data):
    sns.countplot(x=data[column_name], ax=ax[index], color="Orange")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate - Categorical

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 8))
ax = axes.flatten()

for index, column_name in enumerate(categorical_data):
    sns.countplot(x=column_name, hue="GradeClass", data=data, ax=ax[index], palette="Set2")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# ##### How is ParentalEducation and ParentalSupport affecting the GradeClass?

# %%
sns.lineplot(x="ParentalEducation", y="GradeClass", data=data)
# Out:
# <Axes: xlabel='ParentalEducation', ylabel='GradeClass'>

# %%
sns.lineplot(x="ParentalSupport", y="GradeClass", data=data)
# Out:
# <Axes: xlabel='ParentalSupport', ylabel='GradeClass'>

# %%
sns.lineplot(x="ParentalSupport", y="GradeClass", hue="ParentalEducation", data=data)
# Out:
# <Axes: xlabel='ParentalSupport', ylabel='GradeClass'>

# %% [markdown]
# # Data Pre-processing

# %%
data.head()
# Out:
#    Age  Gender  Ethnicity ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17  Female  Caucasian      Some College        19.833723         7
# 1   18    Male  Caucasian       High School        15.408756         0
# 2   15    Male      Asian        Bachelor's         4.210570        26
# 3   17  Female  Caucasian        Bachelor's        10.028829        14
# 4   17  Female  Caucasian      Some College         4.672495        17
#
#    Tutoring ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1        Moderate                0       0      1             0
# 1         0             Low                0       0      0             0
# 2         0        Moderate                0       0      0             0
# 3         0            High                1       0      0             0
# 4         1            High                0       0      0             0
#
#         GPA  GradeClass
# 0  2.929196         2.0
# 1  3.042915         1.0
# ...

# %%
label = data["GradeClass"]

# %%
features = data.drop(["GPA","GradeClass"], axis=1)

# %%
label.head()
# Out:
# 0    2.0
# 1    1.0
# 2    4.0
# 3    3.0
# 4    4.0
# Name: GradeClass, dtype: float64

# %%
features.head()
# Out:
#    Age  Gender  Ethnicity ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17  Female  Caucasian      Some College        19.833723         7
# 1   18    Male  Caucasian       High School        15.408756         0
# 2   15    Male      Asian        Bachelor's         4.210570        26
# 3   17  Female  Caucasian        Bachelor's        10.028829        14
# 4   17  Female  Caucasian      Some College         4.672495        17
#
#    Tutoring ParentalSupport  Extracurricular  Sports  Music  Volunteering
# 0         1        Moderate                0       0      1             0
# 1         0             Low                0       0      0             0
# 2         0        Moderate                0       0      0             0
# 3         0            High                1       0      0             0
# 4         1            High                0       0      0             0

# %%
label.value_counts()
# Out:
# 4.0    1211
# 3.0     414
# 2.0     391
# 1.0     269
# 0.0     107
# Name: GradeClass, dtype: int64

# %%
sns.countplot(x=data["GradeClass"])
# Out:
# <Axes: xlabel='GradeClass', ylabel='count'>

# %%
features.head()
# Out:
#    Age  Gender  Ethnicity ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17  Female  Caucasian      Some College        19.833723         7
# 1   18    Male  Caucasian       High School        15.408756         0
# 2   15    Male      Asian        Bachelor's         4.210570        26
# 3   17  Female  Caucasian        Bachelor's        10.028829        14
# 4   17  Female  Caucasian      Some College         4.672495        17
#
#    Tutoring ParentalSupport  Extracurricular  Sports  Music  Volunteering
# 0         1        Moderate                0       0      1             0
# 1         0             Low                0       0      0             0
# 2         0        Moderate                0       0      0             0
# 3         0            High                1       0      0             0
# 4         1            High                0       0      0             0

# %% [markdown]
# ### Label Encoding

# %%
# sci-kit learn: science-kit learn: sklearn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Intialize the Encoder

encoder = LabelEncoder()

# %%
# step 1: fit

encoder.fit(features["Gender"])
# Out:
# LabelEncoder()

# %%
# step 2: transform
encoder.transform(features["Gender"])
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %%
# Alternatively, lets do step 1 and 2 together:

encoder.fit_transform(features["Gender"])
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %%
features.head()
# Out:
#    Age  Gender  Ethnicity ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17  Female  Caucasian      Some College        19.833723         7
# 1   18    Male  Caucasian       High School        15.408756         0
# 2   15    Male      Asian        Bachelor's         4.210570        26
# 3   17  Female  Caucasian        Bachelor's        10.028829        14
# 4   17  Female  Caucasian      Some College         4.672495        17
#
#    Tutoring ParentalSupport  Extracurricular  Sports  Music  Volunteering
# 0         1        Moderate                0       0      1             0
# 1         0             Low                0       0      0             0
# 2         0        Moderate                0       0      0             0
# 3         0            High                1       0      0             0
# 4         1            High                0       0      0             0

# %% [markdown]
# #### Encode all the categorical column

# %%
for column_name in categorical_data:
    features[column_name] = encoder.fit_transform(features[column_name])

# %%
features.head()
# Out:
#    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17       0          2                  4        19.833723         7
# 1   18       1          2                  1        15.408756         0
# 2   15       1          1                  0         4.210570        26
# 3   17       0          2                  0        10.028829        14
# 4   17       0          2                  4         4.672495        17
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering
# 0         1                2                0       0      1             0
# 1         0                1                0       0      0             0
# 2         0                2                0       0      0             0
# 3         0                0                1       0      0             0
# 4         1                0                0       0      0             0

# %%
data['Ethnicity'].value_counts()
# Out:
# Caucasian           1207
# African American     493
# Asian                470
# Other                222
# Name: Ethnicity, dtype: int64

# %% [markdown]
# ### Split the Data

# %%
print(f"Our data contains {len(features)} records before splitting")
# Out:
# Our data contains 2392 records before splitting

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data = train_test_split(features, test_size=0.2, random_state=42)

# %%
train_data.head()
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 642    18       0          2                  2        18.118879        24
# 1752   16       0          3                  4         2.469271        19
# 1401   17       1          1                  0         3.456401        25
# 2032   17       0          2                  1        15.838131        25
# 990    16       1          2                  3         1.045373        19
#
#       Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering
# 642          1                3                1       1      0             0
# 1752         0                1                0       0      0             1
# 1401         0                3                0       0      0             0
# 2032         1                2                0       0      0             0
# 990          1                2                0       0      1             0

# %%
test_data.head()
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 1004   15       0          1                  2         0.135763        17
# 196    16       0          2                  2         1.989925         0
# 2342   15       1          2                  3        10.588715        15
# 1708   18       0          0                  4        16.208658         1
# 435    18       1          2                  3         3.576821        27
#
#       Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering
# 1004         0                2                0       1      1             1
# 196          0                1                1       0      0             1
# 2342         0                0                0       0      0             1
# 1708         0                0                1       0      0             0
# 435          0                1                0       1      0             0

# %%
len(features) * 0.2
# Out:
# 478.40000000000003

# %%
len(features) * 0.8
# Out:
# 1913.6000000000001

# %%
len(train_data)
# Out:
# 1913

# %%
len(test_data)
# Out:
# 479

# %%
# Features : X-variables
# Label: y-variables

# %%
X_train, X_test, y_train, y_test = train_test_split(features, label, test_size=0.2, random_state=42)

# %% [markdown]
# # Modelling
# #### We'll start with a logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Step 1: Initialize the model

model = LogisticRegression(random_state=42)

# %%
# Step 2: fit/train the model

model.fit(X_train, y_train)
# Out:
# C:\Users\Oladayo\anaconda3\envs\pycaret-env\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
# Step 3: make predictions

predictions = model.predict(X_test)

# %%
X_test.head()
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 1004   15       0          1                  2         0.135763        17
# 196    16       0          2                  2         1.989925         0
# 2342   15       1          2                  3        10.588715        15
# 1708   18       0          0                  4        16.208658         1
# 435    18       1          2                  3         3.576821        27
#
#       Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering
# 1004         0                2                0       1      1             1
# 196          0                1                1       0      0             1
# 2342         0                0                0       0      0             1
# 1708         0                0                1       0      0             0
# 435          0                1                0       1      0             0

# %%
predictions[:5]
# Out:
# array([4., 2., 4., 1., 4.])

# %%
y_test[:5]
# Out:
# 1004    4.0
# 196     1.0
# 2342    2.0
# 1708    0.0
# 435     4.0
# Name: GradeClass, dtype: float64

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
acurracy = accuracy_score(y_test, predictions)

# %%
print(acurracy * 100)
# Out:
# 65.1356993736952

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
report = classification_report(y_test, predictions)
matrix = confusion_matrix(y_test, predictions)

# %%
y_test.value_counts()
# Out:
# 4.0    237
# 3.0     86
# 2.0     85
# 1.0     49
# 0.0     22
# Name: GradeClass, dtype: int64

# %%
print(f"Classification Report\n {report}")
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        22
#          1.0       0.39      0.35      0.37        49
#          2.0       0.45      0.53      0.49        85
#          3.0       0.44      0.30      0.36        86
#          4.0       0.82      0.95      0.88       237
#
#     accuracy                           0.65       479
#    macro avg       0.42      0.42      0.42       479
# weighted avg       0.61      0.65      0.62       479

# %%
len(y_test)
# Out:
# 479

# %%
matrix
# Out:
# array([[  0,  12,   5,   2,   3],
#        [  3,  17,  22,   3,   4],
#        [  1,  13,  45,  18,   8],
#        [  0,   1,  26,  26,  33],
#        [  0,   1,   2,  10, 224]], dtype=int64)

# %%
sns.heatmap(matrix, annot=True, fmt="g")
plt.ylabel("Actual Predictions")
plt.xlabel("Model Predictions")
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Initialize scaler
scaler = MinMaxScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
model = LogisticRegression(random_state=42)
model.fit(X_train_scaled, y_train)
predictions = model.predict(X_test_scaled)

# %%
report = classification_report(y_test, predictions)
matrix = confusion_matrix(y_test, predictions)
print(f"Classification Report\n {report}")
sns.heatmap(matrix, annot=True, fmt="g")
plt.ylabel("Actual Predictions")
plt.xlabel("Model Predictions")
plt.show()
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        22
#          1.0       0.29      0.22      0.25        49
#          2.0       0.43      0.54      0.48        85
#          3.0       0.40      0.21      0.27        86
#          4.0       0.80      0.96      0.87       237
#
#     accuracy                           0.63       479
#    macro avg       0.38      0.39      0.38       479
# weighted avg       0.57      0.63      0.59       479

# %% [markdown]
# ### Can we do better?

# %%
model = LogisticRegression(random_state=42, class_weight={0:2, 1:1.2, 2:1.3, 3:1.2, 4:1})
model.fit(X_train_scaled, y_train)
predictions = model.predict(X_test_scaled)

# %%
report = classification_report(y_test, predictions)
matrix = confusion_matrix(y_test, predictions)
print(f"Classification Report\n {report}")
sns.heatmap(matrix, annot=True, fmt="g")
plt.ylabel("Actual Predictions")
plt.xlabel("Model Predictions")
plt.show()
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.05      0.05      0.05        22
#          1.0       0.14      0.06      0.09        49
#          2.0       0.43      0.60      0.50        85
#          3.0       0.44      0.26      0.32        86
#          4.0       0.82      0.93      0.87       237
#
#     accuracy                           0.62       479
#    macro avg       0.38      0.38      0.37       479
# weighted avg       0.58      0.62      0.59       479

# %%
model = LogisticRegression(random_state=42, class_weight={0:2})
model.fit(X_train_scaled, y_train)
predictions = model.predict(X_test_scaled)
report = classification_report(y_test, predictions)
matrix = confusion_matrix(y_test, predictions)
print(f"Classification Report\n {report}")
sns.heatmap(matrix, annot=True, fmt="g")
plt.ylabel("Actual Predictions")
plt.xlabel("Model Predictions")
plt.show()
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.03      0.05      0.04        22
#          1.0       0.15      0.08      0.11        49
#          2.0       0.46      0.49      0.47        85
#          3.0       0.43      0.22      0.29        86
#          4.0       0.80      0.97      0.88       237
#
#     accuracy                           0.62       479
#    macro avg       0.38      0.36      0.36       479
# weighted avg       0.57      0.62      0.58       479

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Scale the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Train the model
model = LogisticRegression(random_state=42, class_weight={0: 2})
model.fit(X_train_scaled, y_train)

# Step 3: Make predictions
predictions = model.predict(X_test_scaled)

# Step 4: Evaluate the model
report = classification_report(y_test, predictions)
matrix = confusion_matrix(y_test, predictions)

print("Classification Report:\n", report)

# Step 5: Visualise the confusion matrix
sns.heatmap(matrix, annot=True, fmt="g", cmap="Blues")
plt.ylabel("Actual Predictions")
plt.xlabel("Model Predictions")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.09      0.14      0.11        22
#          1.0       0.21      0.12      0.15        49
#          2.0       0.47      0.47      0.47        85
#          3.0       0.43      0.27      0.33        86
#          4.0       0.81      0.95      0.87       237
#
#     accuracy                           0.62       479
#    macro avg       0.40      0.39      0.39       479
# weighted avg       0.59      0.62      0.59       479

# %% [markdown]
# ### Is this the best we can achieve?

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# Initialize and train the models
classifiers = [[LogisticRegression(random_state=42, class_weight={0:2}), 'Logistic Regression'],
               [SGDClassifier(random_state=42, class_weight={0:2}), 'SGD Classifiers'],
               [DecisionTreeClassifier(random_state=42, class_weight={0:2}), 'Decision Tree'],
               [RandomForestClassifier(random_state=42, class_weight={0:2}), 'Random Forest'],
              ]

# %%
for classifier in classifiers:
    print(classifier[1])
# Out:
# Logistic Regression
# SGD Classifiers
# Decision Tree
# Random Forest

# %%
for classifier in classifiers:
    model = classifier[0]
    model_name = classifier[1]
    print(f"<------{model_name}------>")
    model.fit(X_train_scaled, y_train)
    predictions = model.predict(X_test_scaled)
    report = classification_report(y_test, predictions)
    matrix = confusion_matrix(y_test, predictions)
    print(f"Classification Report\n {report}")
    sns.heatmap(matrix, annot=True, fmt="g")
    plt.ylabel("Actual Predictions")
    plt.xlabel("Model Predictions")
    plt.show()
# Out:
# <------Logistic Regression------>
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.09      0.14      0.11        22
#          1.0       0.21      0.12      0.15        49
#          2.0       0.47      0.47      0.47        85
#          3.0       0.43      0.27      0.33        86
#          4.0       0.81      0.95      0.87       237
#
#     accuracy                           0.62       479
#    macro avg       0.40      0.39      0.39       479
# weighted avg       0.59      0.62      0.59       479
# <------SGD Classifiers------>
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.11      0.09      0.10        22
#          1.0       0.27      0.31      0.29        49
#          2.0       0.42      0.31      0.35        85
#          3.0       0.38      0.29      0.33        86
#          4.0       0.80      0.94      0.87       237
#
# ...

# %% [markdown]
# ### Can we still do better?
# #### Do we actually need all of these features

# %%
X_train.head()
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 642    18       0          2                  2        18.118879        24
# 1752   16       0          3                  4         2.469271        19
# 1401   17       1          1                  0         3.456401        25
# 2032   17       0          2                  1        15.838131        25
# 990    16       1          2                  3         1.045373        19
#
#       Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering
# 642          1                3                1       1      0             0
# 1752         0                1                0       0      0             1
# 1401         0                3                0       0      0             0
# 2032         1                2                0       0      0             0
# 990          1                2                0       0      1             0

# %% [markdown]
# ### Feature Importances

# %%
classifiers
# Out:
# [[LogisticRegression(class_weight={0: 2}, random_state=42),
#   'Logistic Regression'],
#  [SGDClassifier(class_weight={0: 2}, random_state=42), 'SGD Classifiers'],
#  [DecisionTreeClassifier(class_weight={0: 2}, random_state=42),
#   'Decision Tree'],
#  [RandomForestClassifier(class_weight={0: 2}, random_state=42),
#   'Random Forest']]

# %%
classifiers[3][0]
# Out:
# RandomForestClassifier(class_weight={0: 2}, random_state=42)

# %%
X_train.head()
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 642    18       0          2                  2        18.118879        24
# 1752   16       0          3                  4         2.469271        19
# 1401   17       1          1                  0         3.456401        25
# 2032   17       0          2                  1        15.838131        25
# 990    16       1          2                  3         1.045373        19
#
#       Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering
# 642          1                3                1       1      0             0
# 1752         0                1                0       0      0             1
# 1401         0                3                0       0      0             0
# 2032         1                2                0       0      0             0
# 990          1                2                0       0      1             0

# %%
feature_importances = classifiers[3][0].feature_importances_

# %%
feature_importances
# Out:
# array([0.06152027, 0.02987677, 0.05774084, 0.06009994, 0.17302252,
#        0.42945304, 0.02420304, 0.06775328, 0.0265783 , 0.0286558 ,
#        0.02193929, 0.01915691])

# %%
feature_names = features.columns

# %%
feature_names
# Out:
# Index(['Age', 'Gender', 'Ethnicity', 'ParentalEducation', 'StudyTimeWeekly',
#        'Absences', 'Tutoring', 'ParentalSupport', 'Extracurricular', 'Sports',
#        'Music', 'Volunteering'],
#       dtype='object')

# %%
feature_importances_df = pd.DataFrame({'Features': feature_names, 'Importances': feature_importances})

# %%
feature_importances_df
# Out:
#              Features  Importances
# 0                 Age     0.061520
# 1              Gender     0.029877
# 2           Ethnicity     0.057741
# 3   ParentalEducation     0.060100
# 4     StudyTimeWeekly     0.173023
# 5            Absences     0.429453
# 6            Tutoring     0.024203
# 7     ParentalSupport     0.067753
# 8     Extracurricular     0.026578
# 9              Sports     0.028656
# 10              Music     0.021939
# 11       Volunteering     0.019157

# %%
feature_importances_df = feature_importances_df.sort_values(by="Importances", ascending=False)

# %%
feature_importances_df
# Out:
#              Features  Importances
# 5            Absences     0.429453
# 4     StudyTimeWeekly     0.173023
# 7     ParentalSupport     0.067753
# 0                 Age     0.061520
# 3   ParentalEducation     0.060100
# 2           Ethnicity     0.057741
# 1              Gender     0.029877
# 9              Sports     0.028656
# 8     Extracurricular     0.026578
# 6            Tutoring     0.024203
# 10              Music     0.021939
# 11       Volunteering     0.019157

# %%
sns.barplot(x="Importances", y="Features", data=feature_importances_df, color="skyblue")
# Out:
# <Axes: xlabel='Importances', ylabel='Features'>

# %% [markdown]
# ### Let select the top 5 features

# %%
feature_importances_df[:5]
# Out:
#             Features  Importances
# 5           Absences     0.429453
# 4    StudyTimeWeekly     0.173023
# 7    ParentalSupport     0.067753
# 0                Age     0.061520
# 3  ParentalEducation     0.060100

# %%
top_5_X = feature_importances_df[:5]

# %%
top_5_X
# Out:
#             Features  Importances
# 5           Absences     0.429453
# 4    StudyTimeWeekly     0.173023
# 7    ParentalSupport     0.067753
# 0                Age     0.061520
# 3  ParentalEducation     0.060100

# %%
top_5_X["Features"].values
# Out:
# array(['Absences', 'StudyTimeWeekly', 'ParentalSupport', 'Age',
#        'ParentalEducation'], dtype=object)

# %%
Xtrain_top_5 = X_train[top_5_X["Features"].values]
Xtest_top_5 = X_test[top_5_X["Features"].values]

# %%
Xtrain_top_5
# Out:
#       Absences  StudyTimeWeekly  ParentalSupport  Age  ParentalEducation
# 642         24        18.118879                3   18                  2
# 1752        19         2.469271                1   16                  4
# 1401        25         3.456401                3   17                  0
# 2032        25        15.838131                2   17                  1
# 990         19         1.045373                2   16                  3
# ...        ...              ...              ...  ...                ...
# 1638        13        13.092424                1   15                  3
# 1095        19         2.159249                4   16                  4
# 1130        14         3.572578                2   16                  4
# 1294        20         4.402585                0   18                  4
# 860         27         5.427628                2   18                  4
#
# [1913 rows x 5 columns]

# %%
Xtrain_top_5_scaled = scaler.fit_transform(Xtrain_top_5)
Xtest_top_5_scaled = scaler.fit_transform(Xtest_top_5)

# %%
for classifier in classifiers:
    model = classifier[0]
    model_name = classifier[1]
    print(f"<------{model_name}------>")
    model.fit(Xtrain_top_5_scaled, y_train)
    predictions = model.predict(Xtest_top_5_scaled)
    report = classification_report(y_test, predictions)
    matrix = confusion_matrix(y_test, predictions)
    print(f"Classification Report\n {report}")
    sns.heatmap(matrix, annot=True, fmt="g")
    plt.ylabel("Actual Predictions")
    plt.xlabel("Model Predictions")
    plt.show()
# Out:
# <------Logistic Regression------>
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.20      0.05      0.07        22
#          1.0       0.42      0.29      0.34        49
#          2.0       0.45      0.58      0.51        85
#          3.0       0.46      0.22      0.30        86
#          4.0       0.78      0.96      0.86       237
#
#     accuracy                           0.65       479
#    macro avg       0.46      0.42      0.42       479
# weighted avg       0.60      0.65      0.61       479
# <------SGD Classifiers------>
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        22
#          1.0       0.00      0.00      0.00        49
#          2.0       0.35      0.49      0.41        85
#          3.0       0.24      0.17      0.20        86
#          4.0       0.79      0.95      0.86       237
#
# ...

# %% [markdown]
# ### Hyper-parameter Tuning using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter_grid = {
    "max_depth": [None, 20, 30, 50],
    "min_samples_split": [5, 7, 10],
    "class_weight": [{0:2}, {0:3}, {0:4}]
}

# %%
grid_search = GridSearchCV(estimator=classifiers[3][0], param_grid=parameter_grid, cv=5, scoring="accuracy")

# %%
grid_search.fit(Xtrain_top_5_scaled, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight={0: 2},
#                                               random_state=42),
#              param_grid={'class_weight': [{0: 2}, {0: 3}, {0: 4}],
#                          'max_depth': [None, 20, 30, 50],
#                          'min_samples_split': [5, 7, 10]},
#              scoring='accuracy')

# %%
print(f"Best Parameters: {grid_search.best_params_}")
# Out:
# Best Parameters: {'class_weight': {0: 2}, 'max_depth': None, 'min_samples_split': 10}

# %%
print(f"Best Score: {grid_search.best_score_}")
# Out:
# Best Score: 0.6805886293111697

# %%
best_model = grid_search.best_estimator_

# %%
predictions = best_model.predict(Xtest_top_5_scaled)
report = classification_report(y_test, predictions)
matrix = confusion_matrix(y_test, predictions)
print(f"Classification Report\n {report}")
sns.heatmap(matrix, annot=True, fmt="g")
plt.ylabel("Actual Predictions")
plt.xlabel("Model Predictions")
plt.show()
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.40      0.18      0.25        22
#          1.0       0.44      0.43      0.43        49
#          2.0       0.49      0.53      0.51        85
#          3.0       0.49      0.40      0.44        86
#          4.0       0.84      0.93      0.88       237
#
#     accuracy                           0.68       479
#    macro avg       0.53      0.49      0.50       479
# weighted avg       0.66      0.68      0.66       479
